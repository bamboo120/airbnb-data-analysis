# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# %matplotlib inline

# %%
#read boston data 
df1 = pd.read_csv('boston.csv')
df1.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
#read seattle data 


df2 = pd.read_csv('seattle.csv')
df2.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df_seattle = df2
df_boston = df1

# %%
# change the data format of price to float
df_seattle['price'] = df_seattle['price'].str.replace('$','')

# %%
df_seattle['price'] = df_seattle['price'].str.replace(',','')

# %%
df_seattle['price'] = df_seattle.price.astype(float)

# %%
#calculate the mean value of the price in seattle
df_seattle['price'].mean()
# Out:
# 137.94485855103355

# %%
# change the data format of price to float

df_boston['price'] = df_boston['price'].str.replace('$','')

# %%
df_boston['price'] = df_boston['price'].str.replace(',','')

# %%
df_boston['price'] = df_boston.price.astype(float)

# %%
#calculate the mean value of the price in boston


df_boston['price'].mean()
# Out:
# 198.43890942511862

# %%
#histogram of price in Boston
plt.hist(df_boston['price'],bins=[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000])
# Out:
# (array([3.07050e+04, 1.68772e+05, 1.02806e+05, 1.00090e+05, 6.72280e+04,
#         5.54840e+04, 3.76420e+04, 2.55220e+04, 1.26840e+04, 1.13810e+04,
#         1.08000e+04, 5.08000e+03, 3.24300e+03, 3.35500e+03, 2.24300e+03,
#         4.55000e+02, 1.11600e+03, 5.75000e+02, 1.66000e+02, 1.58200e+03]),
#  array([   0,   50,  100,  150,  200,  250,  300,  350,  400,  450,  500,
#          550,  600,  650,  700,  750,  800,  850,  900,  950, 1000]),
#  <a list of 20 Patch objects>)

# %%
#histogram of price in Seattle


plt.hist(df_seattle['price'],bins=[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000])
# Out:
# (array([6.31430e+04, 3.54006e+05, 2.28574e+05, 1.28321e+05, 5.82050e+04,
#         4.11430e+04, 1.74340e+04, 1.54900e+04, 7.61700e+03, 7.05400e+03,
#         2.65800e+03, 2.83000e+03, 1.98800e+03, 1.03400e+03, 2.12100e+03,
#         6.82000e+02, 3.19000e+02, 3.16000e+02, 4.08000e+02, 8.72000e+02]),
#  array([   0,   50,  100,  150,  200,  250,  300,  350,  400,  450,  500,
#          550,  600,  650,  700,  750,  800,  850,  900,  950, 1000]),
#  <a list of 20 Patch objects>)

# %%
#below are aimed to calculate the beds information of airbnb
#read in list data have beds information
dflb = pd.read_csv('list_boston.csv')

# %%
dflb = dflb[['id','cancellation_policy','host_since','host_response_time','host_response_rate','host_acceptance_rate','host_has_profile_pic','host_identity_verified','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','price','number_of_reviews','review_scores_rating','instant_bookable','reviews_per_month']]

# %%
dflb.shape[1]
# Out:
# 19

# %%
dfls = pd.read_csv('list_seattle.csv')

# %%
dfls = dfls[['id','cancellation_policy','host_since','host_response_time','host_response_rate','host_acceptance_rate','host_has_profile_pic','host_identity_verified','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','price','number_of_reviews','review_scores_rating','instant_bookable','reviews_per_month']]

# %%
#calculate the beds histogram
dfls['beds'].hist()

# %%
#calculate the beds histogram

dflb['beds'].hist()

# %%
dflb['beds'].mean()
# Out:
# 1.6090604026845639

# %%
dfls['beds'].mean()
# Out:
# 1.7353942887084097

# %%
dfls
# Out:
#             id cancellation_policy  host_since  host_response_time  \
# 0       241032            moderate  2011-08-11  within a few hours
# 1       953595              strict  2013-02-21      within an hour
# 2      3308979              strict  2014-06-12  within a few hours
# 3      7421966            flexible  2013-11-06                 NaN
# 4       278830              strict  2011-11-29      within an hour
# 5      5956968              strict  2010-12-25                 NaN
# 6      1909058            moderate  2012-05-30      within an hour
# 7       856550              strict  2012-10-30      within an hour
# 8      4948745              strict  2012-04-18                 NaN
# 9      2493658              strict  2013-02-21      within an hour
# 10      175576            moderate  2010-09-19  within a few hours
# 11     4454295              strict  2013-01-06  within a few hours
# 12     3883392            moderate  2014-08-13      within an hour
# ...

# %%
dfls['price'] = dfls['price'].str.replace('$','')

# %%
dfls['price'] = dfls['price'].str.replace(',','')

# %%
dfls['price'] = dfls.price.astype(float)

# %%
dfls['price'].mean()
# Out:
# 127.97616553169199

# %%
dfls
# Out:
#             id cancellation_policy  host_since  host_response_time  \
# 0       241032            moderate  2011-08-11  within a few hours
# 1       953595              strict  2013-02-21      within an hour
# 2      3308979              strict  2014-06-12  within a few hours
# 3      7421966            flexible  2013-11-06                 NaN
# 4       278830              strict  2011-11-29      within an hour
# 5      5956968              strict  2010-12-25                 NaN
# 6      1909058            moderate  2012-05-30      within an hour
# 7       856550              strict  2012-10-30      within an hour
# 8      4948745              strict  2012-04-18                 NaN
# 9      2493658              strict  2013-02-21      within an hour
# 10      175576            moderate  2010-09-19  within a few hours
# 11     4454295              strict  2013-01-06  within a few hours
# 12     3883392            moderate  2014-08-13      within an hour
# ...

# %%
dfls['host_response_rate'] = dfls['host_response_rate'].str.replace('%','')

# %%
dfls['host_response_rate'] = dfls.host_response_rate.astype(float)

# %%
dfls['host_acceptance_rate'] = dfls['host_acceptance_rate'].str.replace('%','')

# %%
dfls['host_acceptance_rate'] = dfls.host_acceptance_rate.astype(float)

# %%
dfls = dfls.drop(['host_since'],axis=1)

# %%
dfls = dfls.dropna(subset =['review_scores_rating'])

# %%
dfls
# Out:
#             id cancellation_policy  host_response_time  host_response_rate  \
# 0       241032            moderate  within a few hours                96.0
# 1       953595              strict      within an hour                98.0
# 2      3308979              strict  within a few hours                67.0
# 4       278830              strict      within an hour               100.0
# 5      5956968              strict                 NaN                 NaN
# 6      1909058            moderate      within an hour               100.0
# 7       856550              strict      within an hour               100.0
# 8      4948745              strict                 NaN                 NaN
# 9      2493658              strict      within an hour                98.0
# 10      175576            moderate  within a few hours               100.0
# 11     4454295              strict  within a few hours               100.0
# ...

# %%
dfls.corr()
# Out:
#                             id  host_response_rate  host_acceptance_rate  \
# id                    1.000000            0.010879              0.004098
# host_response_rate    0.010879            1.000000             -0.008278
# host_acceptance_rate  0.004098           -0.008278              1.000000
# accommodates         -0.061873           -0.004066              0.013396
# bathrooms            -0.056656            0.005794              0.008152
# bedrooms             -0.071704           -0.011947              0.006160
# beds                 -0.052407            0.008662              0.012343
# price                -0.053178           -0.037234              0.006162
# number_of_reviews    -0.481861            0.101427              0.010746
# review_scores_rating  0.039246            0.156567             -0.016218
# reviews_per_month     0.094166            0.171433              0.018664
#
#                       accommodates  bathrooms  bedrooms      beds     price  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-135-a84c0541e888> in <module>()
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'
