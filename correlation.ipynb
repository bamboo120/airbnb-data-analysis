# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

# %%
#read in data, and see the correlationship between feathers
dfls = pd.read_csv('list_seattle.csv')

# %%
dfls = dfls[['id','cancellation_policy','guests_included','host_response_time','host_response_rate','host_acceptance_rate','host_has_profile_pic','host_identity_verified','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','price','number_of_reviews','review_scores_rating','instant_bookable','reviews_per_month','review_scores_value','review_scores_location','review_scores_communication','review_scores_checkin','review_scores_cleanliness','review_scores_accuracy']]

# %%
# update value in float
dfls['price'] = dfls['price'].str.replace('$','')

# %%
dfls['price'] = dfls['price'].str.replace(',','')

# %%
dfls['price'] = dfls.price.astype(float)

# %%
dfls['host_response_rate'] = dfls['host_response_rate'].str.replace('%','')

# %%
dfls['host_response_rate'] = dfls.host_response_rate.astype(float)

# %%
dfls['host_acceptance_rate'] = dfls['host_acceptance_rate'].str.replace('%','')

# %%
dfls['host_acceptance_rate'] = dfls.host_acceptance_rate.astype(float)

# %%
# drop unrelated feather
dfls = dfls.drop(['id'],axis=1)

# %%
sns.heatmap?

# %%
dfls
# Out:
#      cancellation_policy  guests_included  host_response_time  \
# 0               moderate                2  within a few hours
# 1                 strict                1      within an hour
# 2                 strict               10  within a few hours
# 3               flexible                1                 NaN
# 4                 strict                6      within an hour
# ...                  ...              ...                 ...
# 3813              strict                1  within a few hours
# 3814            moderate                3      within an hour
# 3815            moderate                2                 NaN
# 3816            moderate                1      within an hour
# 3817            flexible                1        within a day
#
#       host_response_rate  host_acceptance_rate host_has_profile_pic  \
# 0                   96.0                 100.0                    t
# 1                   98.0                 100.0                    t
# 2                   67.0                 100.0                    t
# 3                    NaN                   NaN                    t
# 4                  100.0                   NaN                    t
# ...                  ...                   ...                  ...
# 3813                99.0                 100.0                    t
# 3814               100.0                 100.0                    t
# 3815                 NaN                   NaN                    t
# 3816               100.0                   NaN                    t
# 3817               100.0                   NaN                    t
#
#      host_identity_verified        room_type  accommodates  bathrooms  ...  \
# 0                         t  Entire home/apt             4        1.0  ...
# 1                         t  Entire home/apt             4        1.0  ...
# 2                         t  Entire home/apt            11        4.5  ...
# 3                         t  Entire home/apt             3        1.0  ...
# 4                         t  Entire home/apt             6        2.0  ...
# ...                     ...              ...           ...        ...  ...
# 3813                      t  Entire home/apt             6        2.0  ...
# 3814                      t  Entire home/apt             4        1.0  ...
# 3815                      f  Entire home/apt             2        1.0  ...
# 3816                      t  Entire home/apt             2        1.0  ...
# 3817                      t  Entire home/apt             3        1.5  ...
#
#       number_of_reviews  review_scores_rating instant_bookable  \
# 0                   207                  95.0                f
# 1                    43                  96.0                f
# 2                    20                  97.0                f
# 3                     0                   NaN                f
# 4                    38                  92.0                f
# ...                 ...                   ...              ...
# 3813                  1                  80.0                f
# 3814                  2                 100.0                f
# 3815                  0                   NaN                f
# 3816                  0                   NaN                f
# 3817                  0                   NaN                f
#
#       reviews_per_month  review_scores_value  review_scores_location  \
# 0                  4.07                 10.0                     9.0
# 1                  1.48                 10.0                    10.0
# 2                  1.15                 10.0                    10.0
# 3                   NaN                  NaN                     NaN
# 4                  0.89                  9.0                     9.0
# ...                 ...                  ...                     ...
# 3813               0.30                  8.0                    10.0
# 3814               2.00                 10.0                    10.0
# 3815                NaN                  NaN                     NaN
# 3816                NaN                  NaN                     NaN
# 3817                NaN                  NaN                     NaN
#
#      review_scores_communication  review_scores_checkin  \
# 0                           10.0                   10.0
# 1                           10.0                   10.0
# 2                           10.0                   10.0
# 3                            NaN                    NaN
# 4                           10.0                   10.0
# ...                          ...                    ...
# 3813                         8.0                    4.0
# 3814                        10.0                   10.0
# 3815                         NaN                    NaN
# 3816                         NaN                    NaN
# 3817                         NaN                    NaN
#
#       review_scores_cleanliness  review_scores_accuracy
# 0                          10.0                    10.0
# 1                          10.0                    10.0
# 2                          10.0                    10.0
# 3                           NaN                     NaN
# 4                           9.0                     9.0
# ...                         ...                     ...
# 3813                       10.0                     8.0
# 3814                       10.0                    10.0
# 3815                        NaN                     NaN
# 3816                        NaN                     NaN
# 3817                        NaN                     NaN
#
# [3818 rows x 24 columns]

# %%
# create the map of correlation
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(dfls.corr(), annot=True, fmt=".2f",linewidths=.5,ax =ax);

# %%
dflb = pd.read_csv('list_boston.csv')

# %%
dflb = dflb[['id','cancellation_policy','guests_included','host_response_time','host_response_rate','host_acceptance_rate','host_has_profile_pic','host_identity_verified','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','price','number_of_reviews','review_scores_rating','instant_bookable','reviews_per_month','review_scores_value','review_scores_location','review_scores_communication','review_scores_checkin','review_scores_cleanliness','review_scores_accuracy']]

# %%
# update value in float


dflb['price'] = dflb['price'].str.replace('$','')
dflb['price'] = dflb['price'].str.replace(',','')
dflb['price'] = dflb.price.astype(float)
dflb['host_response_rate'] = dflb['host_response_rate'].str.replace('%','')
dflb['host_response_rate'] = dflb.host_response_rate.astype(float)
dflb['host_acceptance_rate'] = dflb['host_acceptance_rate'].str.replace('%','')
dflb['host_acceptance_rate'] = dflb.host_acceptance_rate.astype(float)
dflb = dflb.drop(['id'],axis=1)

# %%
# create the map of correlation


fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(dflb.corr(), annot=True, fmt=".2f",linewidths=.5,ax =ax);
